# %%
import openai
from dotenv import load_dotenv, find_dotenv

_ = load_dotenv(find_dotenv())

client = openai.Client()

# %%
resposta = client.chat.completions.create(
    model='gpt-4o',
    messages=[{
        'role':'user',
        'content':[
            {'type':'text', 'text':'Descreva a imagem fornecida'},
            {'type':'image_url', 'image_url':{'url':'https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg'}}
        ]
    }]
)

# %%
print(resposta.choices[0].message.content)
# Out:
# A imagem mostra uma paisagem natural com um céu azul e algumas nuvens leves. Há um caminho de madeira que se estende pela grama verde. Árvores e arbustos são visíveis ao fundo, criando um ambiente tranquilo e aberto.

# %%
import base64

def encode_image(caminho_imagem):
    with open(caminho_imagem, 'rb') as img:
        return base64.b64encode(img.read()).decode('utf-8')
    
caminho = 'imagens-vision/celulas.jpg'
base_64_img = encode_image(caminho)

resposta = client.chat.completions.create(
    model='gpt-4o',
    messages=[{
        'role':'user',
        'content':[
            {'type':'text', 'text':'Quantas células aparecem na imagem?'},
            {'type':'image_url', 'image_url':{'url':f'data:image/jpg;base64,{base_64_img}'}}
        ]
    }],
    max_tokens=1000
)

# %%
print(resposta.choices[0].message.content)
# Out:
# A imagem mostra nove células fluorescentes.

# %% [markdown]
# ### OCR com o GPT Vision

# %%
import base64

def encode_image(caminho_imagem):
    with open(caminho_imagem, 'rb') as img:
        return base64.b64encode(img.read()).decode('utf-8')
    
caminho = 'imagens-vision/escrito_mao_facil.jpg'
base_64_img = encode_image(caminho)

resposta = client.chat.completions.create(
    model='gpt-4o',
    messages=[{
        'role':'user',
        'content':[
            {'type':'text', 'text':'O que está escrito na imagem?'},
            {'type':'image_url', 'image_url':{'url':f'data:image/jpg;base64,{base_64_img}'}}
        ]
    }],
    max_tokens=1000
)

print(resposta.choices[0].message.content)
# Out:
# A imagem mostra as palavras "Follow your dream..." escritas em um caderno.

# %%
import base64

def encode_image(caminho_imagem):
    with open(caminho_imagem, 'rb') as img:
        return base64.b64encode(img.read()).decode('utf-8')
    
caminho = 'imagens-vision/escrito_mao_medio.jpg'
base_64_img = encode_image(caminho)

resposta = client.chat.completions.create(
    model='chatgpt-4o-latest',
    messages=[{
        'role':'user',
        'content':[
            {'type':'text', 'text':'O que está escrito na imagem?'},
            {'type':'image_url', 'image_url':{'url':f'data:image/jpg;base64,{base_64_img}'}}
        ]
    }],
    max_tokens=1000
)

print(resposta.choices[0].message.content)
# Out:
# O que está escrito na imagem é:
#
# **"Fui no mercadinho...
# Já volto ❤
# PS: te amo ❤"**

# %%
import base64

def encode_image(caminho_imagem):
    with open(caminho_imagem, 'rb') as img:
        return base64.b64encode(img.read()).decode('utf-8')
    
caminho = 'imagens-vision/layout.jpg'
base_64_img = encode_image(caminho)

resposta = client.chat.completions.create(
    model='chatgpt-4o-latest',
    messages=[{
        'role':'user',
        'content':[
            {'type':'text', 'text':'''
                Crie um novo layout para esta página. 
                Quero um layout que gere uma melhor experiência de usuário.
                Retorne os códigos HTML e CSS da página nova.
             '''},
            {'type':'image_url', 'image_url':{'url':f'data:image/jpg;base64,{base_64_img}'}}
        ]
    }],
    max_tokens=4096
)

print(resposta.choices[0].message.content)
# Out:
# Segue abaixo um layout repaginado para melhorar a experiência do usuário na página. A proposta visa criar um design limpo, leve e intuitivo, com componentes mais organizados visualmente e um destaque maior para a funcionalidade de busca e filtros.
#
# ### Código HTML:
# ```html
# <!DOCTYPE html>
# <html lang="pt-br">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Tutoriais da Asimov</title>
#   <link rel="stylesheet" href="styles.css">
# </head>
# <body>
#   <header>
#     <div class="header-content">
#       <h1>Conheça os <strong>Tutoriais da Asimov</strong></h1>
#       <div class="search-bar">
#         <input type="text" placeholder="Pesquisar tutoriais...">
#         <button aria-label="Pesquisar">
#           <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24" width="24" height="24">
#             <path d="M21 21l-6-6m0-5a7 7 0 1 0-14 0 7 7 0 0 0 14 0z" stroke="#fff" stroke-width="2" fill="none" stroke-linecap="round"></path>
#           </svg>
#         </button>
#       </div>
#     </div>
#   </header>
#
#   <main>
#     <section class="filters">
#       <div>
#         <label for="categoria">Categoria:</label>
#         <select id="categoria">
#           <option value="todas">Todas Categorias</option>
#           <option value="graficos">Gráficos</option>
#           <option value="dataframe">DataFrame</option>
#         </select>
#       </div>
#       <div>
#         <label for="nivel">Nível:</label>
#         <select id="nivel">
#           <option value="todos">Todos os Níveis</option>
#           <option value="iniciante">Iniciante</option>
#           <option value="intermediario">Intermediário</option>
#           <option value="avancado">Avançado</option>
#         </select>
#       </div>
#       <button class="btn-filtrar">Filtrar</button>
#     </section>
#
#     <section class="tutorial-list">
#       <div class="tutorial-card">
#         <div class="tags">
#           <span>gráficos</span>
#           <span>legendas</span>
#           <span>matplotlib</span>
#         </div>
#         <h2>Como Estilizar a Legenda de Gráficos com Matplotlib</h2>
#         <p>Ana Maria Gomes • 21-03-24</p>
#       </div>
#       <div class="tutorial-card">
#         <div class="tags">
#           <span>pandas</span>
#           <span>manipulação de dados</span>
#         </div>
#         <h2>Concat no pandas: entendendo e usando o método pd.concat</h2>
#         <p>Juliano Faccioni • 21-03-24</p>
#       </div>
#       <!-- Adicione mais cards conforme necessário -->
#     </section>
#   </main>
# </body>
# </html>
# ```
#
# ### Código CSS (arquivo `styles.css`):
# ```css
# :root {
#   --background: #121212;
#   --card-bg: #1e1e1e;
#   --accent: #46d4a0;
#   --text-primary: #ffffff;
#   --text-secondary: #b3b3b3;
#   --border-radius: 8px;
# }
#
# * {
#   margin: 0;
#   padding: 0;
#   box-sizing: border-box;
# }
#
# body {
#   font-family: Arial, sans-serif;
#   background: var(--background);
#   color: var(--text-primary);
#   line-height: 1.6;
# }
#
# header {
#   padding: 2rem;
#   background: var(--accent);
#   color: var(--background);
#   text-align: center;
# }
#
# .header-content h1 {
#   font-size: 2rem;
# }
#
# .search-bar {
#   margin-top: 1rem;
#   display: flex;
#   justify-content: center;
#   align-items: center;
# }
#
# .search-bar input {
#   padding: 0.8rem;
#   font-size: 1rem;
#   border: none;
#   border-radius: var(--border-radius) 0 0 var(--border-radius);
#   width: 300px;
#   outline: none;
# }
#
# .search-bar button {
#   padding: 0.8rem;
#   border: none;
#   background: var(--background);
#   color: var(--text-primary);
#   cursor: pointer;
#   border-radius: 0 var(--border-radius) var(--border-radius) 0;
# }
#
# main {
#   padding: 2rem;
# }
#
# .filters {
#   display: flex;
#   justify-content: center;
#   gap: 1rem;
#   margin-bottom: 2rem;
# }
#
# .filters label {
#   display: block;
#   margin-bottom: 0.5rem;
# }
#
# .filters select {
#   padding: 0.5rem;
#   border-radius: var(--border-radius);
#   background: var(--card-bg);
#   color: var(--text-primary);
#   border: none;
# }
#
# .btn-filtrar {
#   padding: 0.8rem 1.5rem;
#   border: none;
#   background: var(--accent);
#   color: var(--background);
#   border-radius: var(--border-radius);
#   cursor: pointer;
#   font-weight: bold;
# }
#
# .tutorial-list {
#   display: grid;
#   grid-template-columns: repeat(auto-fit, minmax(300px, 1fr));
#   gap: 1.5rem;
# }
#
# .tutorial-card {
#   background: var(--card-bg);
#   padding: 1.5rem;
#   border-radius: var(--border-radius);
# }
#
# .tutorial-card h2 {
#   font-size: 1.5rem;
#   margin: 1rem 0;
#   color: var(--text-primary);
# }
#
# .tutorial-card p {
#   color: var(--text-secondary);
# }
#
# .tags span {
#   display: inline-block;
#   margin-right: 0.5rem;
#   background: var(--accent);
#   color: var(--background);
#   border-radius: var(--border-radius);
#   padding: 0.2rem 0.5rem;
#   font-size: 0.875rem;
# }
# ```
#
# Agora você tem uma página com uma experiência melhorada. A hierarchy visual coloca mais ênfase na pesquisa e os filtros são mais claros. Elementos estão bem espaçados e organizados.
